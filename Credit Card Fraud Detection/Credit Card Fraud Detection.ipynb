# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn import preprocessing
from sklearn import model_selection
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score,auc, accuracy_score

from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import train_test_split

from IPython.core.display import HTML # permet d'afficher du code html dans jupyter
from collections import Counter

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_recall_curve, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier

# %%
df = pd.read_csv(r"C:\Users\KIIT\OneDrive\Desktop\Python\creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Find the shape of dataset

df.shape
# Out:
# (284807, 31)

# %%
# Find the datatype of each attribute

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# Statistics for numeric attributes

df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759061e-12 -8.251130e-13 -9.654937e-13  8.321385e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.649999e-13  4.248366e-13 -3.054600e-13  8.777971e-14 -1.179749e-12
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ... -3.405756e-13 -5.723197e-13 -9.725856e-13  1.464150e-12
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean  -6.987102e-13 -5.617874e-13  3.332082e-12 -3.518874e-12      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
# Check for duplicates

duplicate = df[df.duplicated()]
duplicate
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 33      0.711206  0.176066 -0.286717  ...  0.046949  0.208105 -0.185548
# 35      0.693039  0.179742 -0.285642  ...  0.049526  0.206537 -0.187108
# 113    -0.036715  0.350995  0.118950  ...  0.102520  0.605089  0.023092
# 114    -0.036715  0.350995  0.118950  ...  0.102520  0.605089  0.023092
# 115    -0.036715  0.350995  0.118950  ...  0.102520  0.605089  0.023092
# ...          ...       ...       ...  ...       ...       ...       ...
# 282987 -0.881302  1.081750  1.022928  ... -0.524067 -1.337510  0.473943
# 283483 -0.303778  0.884953  0.054065  ...  0.287217  0.947825 -0.218773
# 283485 -0.282535  0.880654  0.052808  ...  0.284205  0.949659 -0.216949
# 284191 -0.667233  2.309700 -1.639306  ...  0.391483  0.266536 -0.079853
# 284193 -0.745886  2.325616 -1.634651  ...  0.402639  0.259746 -0.086606
#
#              V24       V25       V26       V27       V28  Amount  Class
# 33      0.001031  0.098816 -0.552904 -0.073288  0.023307    6.14      0
# 35      0.000753  0.098117 -0.553471 -0.078306  0.025427    1.77      0
# 113    -0.626463  0.479120 -0.166937  0.081247  0.001192    1.18      0
# 114    -0.626463  0.479120 -0.166937  0.081247  0.001192    1.18      0
# 115    -0.626463  0.479120 -0.166937  0.081247  0.001192    1.18      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 282987  0.616683 -0.283548 -1.084843  0.073133 -0.036020   11.99      0
# 283483  0.082926  0.044127  0.639270  0.213565  0.119251    6.82      0
# 283485  0.083250  0.044944  0.639933  0.219432  0.116772   11.93      0
# 284191 -0.096395  0.086719 -0.451128 -1.183743 -0.222200   55.66      0
# 284193 -0.097597  0.083693 -0.453584 -1.205466 -0.213020   36.74      0
#
# [1081 rows x 31 columns]

# %%
# Remove duplicate records except the first occurence

df.drop_duplicates(inplace=True)

# %%
# Again check if any duplicate records are left

duplicate = df[df.duplicated()] 
duplicate
# Out:
# Empty DataFrame
# Columns: [Time, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount, Class]
# Index: []
#
# [0 rows x 31 columns]

# %%
# Find the total number of missing values in each column

df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Checking the shape again

df.shape
# Out:
# (283726, 31)

# %%
# PLot Correlation Matrix

corr = df.corr()
corr.style.background_gradient(cmap='PuBu').set_precision(2)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_8832\1240934339.py:4: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='PuBu').set_precision(2)
# <style type="text/css">
# #T_18dfa_row0_col0, #T_18dfa_row1_col1, #T_18dfa_row2_col2, #T_18dfa_row3_col3, #T_18dfa_row4_col4, #T_18dfa_row5_col5, #T_18dfa_row6_col6, #T_18dfa_row7_col7, #T_18dfa_row8_col8, #T_18dfa_row9_col9, #T_18dfa_row10_col10, #T_18dfa_row11_col11, #T_18dfa_row12_col12, #T_18dfa_row13_col13, #T_18dfa_row14_col14, #T_18dfa_row15_col15, #T_18dfa_row16_col16, #T_18dfa_row17_col17, #T_18dfa_row18_col18, #T_18dfa_row19_col19, #T_18dfa_row20_col20, #T_18dfa_row21_col21, #T_18dfa_row22_col22, #T_18dfa_row23_col23, #T_18dfa_row24_col24, #T_18dfa_row25_col25, #T_18dfa_row26_col26, #T_18dfa_row27_col27, #T_18dfa_row28_col28, #T_18dfa_row29_col29, #T_18dfa_row30_col30 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_18dfa_row0_col1, #T_18dfa_row2_col5 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_18dfa_row0_col2, #T_18dfa_row0_col29, #T_18dfa_row12_col29 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_18dfa_row0_col3, #T_18dfa_row0_col4, #T_18dfa_row0_col6, #T_18dfa_row0_col11, #T_18dfa_row0_col13, #T_18dfa_row0_col15, #T_18dfa_row0_col20, #T_18dfa_row0_col24, #T_18dfa_row0_col25, #T_18dfa_row0_col26, #T_18dfa_row1_col27, #T_18dfa_row2_col21, #T_18dfa_row2_col29, #T_18dfa_row3_col0, #T_18dfa_row11_col21, #T_18dfa_row17_col30, #T_18dfa_row23_col21, #T_18dfa_row27_col21, #T_18dfa_row27_col28, #T_18dfa_row28_col21, #T_18dfa_row28_col27, #T_18dfa_row29_col1, #T_18dfa_row29_col2, #T_18dfa_row29_col5, #T_18dfa_row29_col8, #T_18dfa_row29_col19, #T_18dfa_row29_col22, #T_18dfa_row29_col23, #T_18dfa_row30_col7, #T_18dfa_row30_col9, #T_18dfa_row30_col10, #T_18dfa_row30_col12, #T_18dfa_row30_col14, #T_18dfa_row30_col16, #T_18dfa_row30_col17, #T_18dfa_row30_col18 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_18dfa_row0_col5, #T_18dfa_row30_col2 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_18dfa_row0_col7, #T_18dfa_row4_col0, #T_18dfa_row8_col14, #T_18dfa_row12_col14, #T_18dfa_row16_col14 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_18dfa_row0_col8, #T_18dfa_row1_col6, #T_18dfa_row1_col13, #T_18dfa_row1_col22, #T_18dfa_row2_col6, #T_18dfa_row2_col22, #T_18dfa_row3_col13, #T_18dfa_row3_col22, #T_18dfa_row4_col6, #T_18dfa_row4_col13, #T_18dfa_row4_col22, #T_18dfa_row5_col6, #T_18dfa_row5_col13, #T_18dfa_row5_col22, #T_18dfa_row6_col13, #T_18dfa_row6_col22, #T_18dfa_row7_col6, #T_18dfa_row7_col13, #T_18dfa_row7_col22, #T_18dfa_row8_col6, #T_18dfa_row8_col13, #T_18dfa_row9_col6, #T_18dfa_row9_col22, #T_18dfa_row10_col22, #T_18dfa_row11_col6, #T_18dfa_row11_col13, #T_18dfa_row11_col22, #T_18dfa_row12_col13, #T_18dfa_row12_col22, #T_18dfa_row13_col6, #T_18dfa_row13_col22, #T_18dfa_row14_col6, #T_18dfa_row14_col13, #T_18dfa_row14_col22, #T_18dfa_row15_col6, #T_18dfa_row15_col13, #T_18dfa_row15_col22, #T_18dfa_row16_col6, #T_18dfa_row16_col13, #T_18dfa_row16_col22, #T_18dfa_row17_col13, #T_18dfa_row17_col22, #T_18dfa_row18_col6, #T_18dfa_row18_col13, #T_18dfa_row18_col22, #T_18dfa_row19_col6, #T_18dfa_row19_col13, #T_18dfa_row19_col22, #T_18dfa_row20_col6, #T_18dfa_row20_col13, #T_18dfa_row20_col22, #T_18dfa_row21_col13, #T_18dfa_row22_col6, #T_18dfa_row22_col13, #T_18dfa_row23_col6, #T_18dfa_row23_col13, #T_18dfa_row24_col6, #T_18dfa_row24_col13, #T_18dfa_row24_col22, #T_18dfa_row25_col6, #T_18dfa_row25_col13, #T_18dfa_row25_col22, #T_18dfa_row26_col6, #T_18dfa_row26_col13, #T_18dfa_row26_col22, #T_18dfa_row27_col6, #T_18dfa_row27_col13, #T_18dfa_row28_col6, #T_18dfa_row28_col13, #T_18dfa_row28_col22 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_18dfa_row0_col9, #T_18dfa_row0_col19, #T_18dfa_row7_col9, #T_18dfa_row10_col30 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_18dfa_row0_col10, #T_18dfa_row0_col22, #T_18dfa_row1_col29, #T_18dfa_row2_col11, #T_18dfa_row3_col12, #T_18dfa_row4_col11, #T_18dfa_row5_col12, #T_18dfa_row6_col11, #T_18dfa_row7_col12, #T_18dfa_row8_col12, #T_18dfa_row9_col11, #T_18dfa_row9_col12, #T_18dfa_row15_col11, #T_18dfa_row18_col12, #T_18dfa_row19_col11, #T_18dfa_row20_col11, #T_18dfa_row21_col11, #T_18dfa_row22_col11, #T_18dfa_row23_col11, #T_18dfa_row24_col11, #T_18dfa_row25_col11, #T_18dfa_row26_col11, #T_18dfa_row29_col11 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_18dfa_row0_col12, #T_18dfa_row2_col30 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_18dfa_row0_col14, #T_18dfa_row0_col23, #T_18dfa_row4_col7, #T_18dfa_row6_col7, #T_18dfa_row11_col7, #T_18dfa_row12_col16, #T_18dfa_row13_col7, #T_18dfa_row14_col16, #T_18dfa_row15_col7, #T_18dfa_row17_col16, #T_18dfa_row19_col7, #T_18dfa_row20_col7, #T_18dfa_row22_col7, #T_18dfa_row23_col7, #T_18dfa_row24_col7, #T_18dfa_row25_col7, #T_18dfa_row26_col7, #T_18dfa_row28_col7, #T_18dfa_row29_col3, #T_18dfa_row29_col25 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_18dfa_row0_col16, #T_18dfa_row1_col30, #T_18dfa_row5_col10, #T_18dfa_row9_col30, #T_18dfa_row12_col10, #T_18dfa_row15_col0, #T_18dfa_row17_col10, #T_18dfa_row20_col10 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_18dfa_row0_col17, #T_18dfa_row3_col1, #T_18dfa_row5_col1, #T_18dfa_row27_col10, #T_18dfa_row28_col1 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_18dfa_row0_col18, #T_18dfa_row7_col1, #T_18dfa_row28_col10 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_18dfa_row0_col21, #T_18dfa_row1_col19, #T_18dfa_row2_col19, #T_18dfa_row3_col6, #T_18dfa_row3_col19, #T_18dfa_row4_col19, #T_18dfa_row5_col19, #T_18dfa_row6_col19, #T_18dfa_row7_col19, #T_18dfa_row8_col19, #T_18dfa_row8_col22, #T_18dfa_row9_col19, #T_18dfa_row10_col6, #T_18dfa_row10_col19, #T_18dfa_row11_col19, #T_18dfa_row12_col6, #T_18dfa_row12_col19, #T_18dfa_row13_col19, #T_18dfa_row14_col19, #T_18dfa_row14_col20, #T_18dfa_row15_col19, #T_18dfa_row16_col19, #T_18dfa_row17_col6, #T_18dfa_row17_col19, #T_18dfa_row18_col19, #T_18dfa_row20_col19, #T_18dfa_row21_col6, #T_18dfa_row21_col19, #T_18dfa_row21_col20, #T_18dfa_row22_col19, #T_18dfa_row23_col19, #T_18dfa_row24_col19, #T_18dfa_row25_col19, #T_18dfa_row26_col19, #T_18dfa_row27_col19, #T_18dfa_row28_col19, #T_18dfa_row28_col20, #T_18dfa_row30_col13 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_18dfa_row0_col27, #T_18dfa_row1_col21, #T_18dfa_row1_col28, #T_18dfa_row3_col21, #T_18dfa_row3_col27, #T_18dfa_row5_col21, #T_18dfa_row5_col27, #T_18dfa_row7_col27, #T_18dfa_row10_col21, #T_18dfa_row12_col21, #T_18dfa_row14_col27, #T_18dfa_row14_col28, #T_18dfa_row16_col21, #T_18dfa_row16_col27, #T_18dfa_row17_col21, #T_18dfa_row17_col28, #T_18dfa_row18_col21, #T_18dfa_row18_col27, #T_18dfa_row20_col21, #T_18dfa_row21_col27, #T_18dfa_row21_col28, #T_18dfa_row23_col28, #T_18dfa_row30_col24 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_18dfa_row0_col28, #T_18dfa_row4_col21, #T_18dfa_row6_col21, #T_18dfa_row9_col21, #T_18dfa_row13_col21, #T_18dfa_row15_col21, #T_18dfa_row19_col21, #T_18dfa_row24_col21, #T_18dfa_row25_col21, #T_18dfa_row26_col21 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_18dfa_row0_col30, #T_18dfa_row2_col14, #T_18dfa_row4_col14, #T_18dfa_row6_col14, #T_18dfa_row9_col14, #T_18dfa_row10_col14, #T_18dfa_row12_col17, #T_18dfa_row14_col17, #T_18dfa_row15_col14, #T_18dfa_row19_col14, #T_18dfa_row20_col14, #T_18dfa_row23_col14, #T_18dfa_row24_col14, #T_18dfa_row25_col14 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_18dfa_row1_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_18dfa_row1_col2, #T_18dfa_row7_col2, #T_18dfa_row11_col30, #T_18dfa_row17_col29, #T_18dfa_row27_col2, #T_18dfa_row28_col29, #T_18dfa_row30_col29 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_18dfa_row1_col3, #T_18dfa_row2_col0, #T_18dfa_row5_col3, #T_18dfa_row9_col0, #T_18dfa_row10_col3, #T_18dfa_row12_col3, #T_18dfa_row17_col3, #T_18dfa_row27_col3, #T_18dfa_row28_col0, #T_18dfa_row29_col0 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_18dfa_row1_col4, #T_18dfa_row1_col23, #T_18dfa_row2_col23, #T_18dfa_row3_col4, #T_18dfa_row3_col23, #T_18dfa_row3_col30, #T_18dfa_row4_col23, #T_18dfa_row5_col2

# %%
# Plot class distribution

sns.countplot(data=df, x='Class')
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
# Splitting the dataset into train and test sets

X = df.iloc[:, :-1].to_numpy()
y = df['Class'].to_numpy()

# %%
# Generate and plot a synthetic imbalanced classification dataset

counter = Counter(y)
print(counter)

# Scatter plot of 'Class' by class label
for label, _ in counter.items():
    row_ix = np.where(y == label)[0]
    plt.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
plt.legend()
plt.show()
# Out:
# Counter({0: 284315, 1: 492})

# %%
# Transform the dataset

sm = SMOTE(random_state=0)
X, y = sm.fit_resample(X, y)

# %%
counter = Counter(y)
print(counter)

# Scatter plot of 'Class' by class label
for label, _ in counter.items():
    row_ix = np.where(y == label)[0]
    plt.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
plt.legend()
plt.show()
# Out:
# Counter({0: 284315, 1: 284315})

# %%
# Split dataset into train and test sets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (454904, 30)
# X_test: (113726, 30)
# y_train: (454904,)
# y_test: (113726,)

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Score of train data:", dt.score(X_train, y_train))
print("Score of test data:", dt.score(X_test, y_test))
# Out:
# Score of train data: 1.0
# Score of test data: 0.9986019028190564

# %%
y_pred = dt.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 0, 0, 1], dtype=int64)

# %%
print("Accuracy Score:", accuracy_score(y_pred, y_test))
# Out:
# Accuracy Score: 0.9986019028190564

# %%
y_pred_prob = dt.predict_proba(X_test)[:,1]
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision Recall Curve')
# Out:
# Text(0.5, 1.0, 'Precision Recall Curve')

# %%
# Confusion Matrix

cm = confusion_matrix(y_test, y_pred)

ax= plt.subplot()
sns.heatmap(cm, annot=True, ax=ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X = df.drop(['Class'], axis=1)
#       4 y = df.Class
#       5 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
#
# NameError: name 'df' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Initialising the ANN
# ----> 2 classifier = Sequential()
#       3 classifier.add(Dense(units=30, kernel_initializer='he_uniform', activation='relu', input_dim = 30))
#       4 classifier.add(Dense(units=50, kernel_initializer='he_uniform', activation='relu'))
#
# NameError: name 'Sequential' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.isnull().values.sum()
#
# NameError: name 'df' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("creditcard.csv")
#
# NameError: name 'pd' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X = df.drop(['Class'], axis=1)
#       4 y = df.Class
#       5 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
#
# NameError: name 'df' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X = df.drop(['Class'], axis=1)
#       4 y = df.Class
#       5 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
#
# NameError: name 'df' is not defined

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['Class'], axis=1)
y = df.Class
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X = df.drop(['Class'], axis=1)
#       4 y = df.Class
#       5 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
#
# NameError: name 'df' is not defined
